# %%
import json
import requests
import pandas as pd

# %%
base_url = requests.get("https://pokeapi.co/api/v2/")

# %%
urls = base_url.json()

# %%
endpoints = pd.DataFrame.from_dict(urls,orient='index', columns = ['url'])

# %%
column_names = ["count"]
services_count = pd.DataFrame(columns=column_names)

# %%
for index, row in endpoints1.iterrows():
    url1 = row["url"]
    print (url1)
    new = requests.get(url1).json()
    services_count.at[index, "count"] = new["count"]
# Out:
# https://pokeapi.co/api/v2/ability/
# https://pokeapi.co/api/v2/berry/
# https://pokeapi.co/api/v2/berry-firmness/
# https://pokeapi.co/api/v2/berry-flavor/
# https://pokeapi.co/api/v2/characteristic/
# https://pokeapi.co/api/v2/contest-effect/
# https://pokeapi.co/api/v2/contest-type/
# https://pokeapi.co/api/v2/egg-group/
# https://pokeapi.co/api/v2/encounter-condition/
# https://pokeapi.co/api/v2/encounter-condition-value/
# https://pokeapi.co/api/v2/encounter-method/
# https://pokeapi.co/api/v2/evolution-chain/
# https://pokeapi.co/api/v2/evolution-trigger/
# https://pokeapi.co/api/v2/gender/
# https://pokeapi.co/api/v2/generation/
# https://pokeapi.co/api/v2/growth-rate/
# https://pokeapi.co/api/v2/item/
# https://pokeapi.co/api/v2/item-attribute/
# https://pokeapi.co/api/v2/item-category/
# https://pokeapi.co/api/v2/item-fling-effect/
# https://pokeapi.co/api/v2/item-pocket/
# https://pokeapi.co/api/v2/language/
# https://pokeapi.co/api/v2/location/
# ...

# %%
services_count
# Out:
#                           count
# ability                     327
# berry                        64
# berry-firmness                5
# berry-flavor                  5
# characteristic               30
# contest-effect               33
# contest-type                  5
# egg-group                    15
# encounter-condition          10
# encounter-condition-value    39
# encounter-method             27
# evolution-chain             467
# evolution-trigger             5
# gender                        3
# generation                    8
# growth-rate                   6
# item                        954
# item-attribute                8
# item-category                45
# item-fling-effect             7
# item-pocket                   8
# language                     13
# location                    796
# location-area               702
# machine                    1442
# move                        844
# move-ailment                 21
# move-battle-style             3
# ...
